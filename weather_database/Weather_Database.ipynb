# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 808

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_weather_desc = city_weather["weather"][0]["description"]
          # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')         
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | henties bay
# Processing Record 6 of Set 1 | torbay
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | aripuana
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | itarema
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | mehamn
# Processing Record 15 of Set 1 | west bay
# Processing Record 16 of Set 1 | korla
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | siyabuswa
# Processing Record 20 of Set 1 | macheng
# Processing Record 21 of Set 1 | hanstholm
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | imeni poliny osipenko
# Processing Record 25 of Set 1 | katherine
# Processing Record 26 of Set 1 | cabedelo
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | yumen
# Processing Record 29 of Set 1 | bandipur
# Processing Record 30 of Set 1 | cayenne
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | navolato
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | zyryanka
# Processing Record 36 of Set 1 | san quintin
# Processing Record 37 of Set 1 | salalah
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | bantou
# Processing Record 40 of Set 1 | olafsvik
# Processing Record 41 of Set 1 | isilkul
# Processing Record 42 of Set 1 | ratholo
# Processing Record 43 of Set 1 | dengfeng
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | north battleford
# Processing Record 47 of Set 1 | baiao
# Processing Record 48 of Set 1 | pathein
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | qandala
# Processing Record 4 of Set 2 | san vicente
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | lagoa
# Processing Record 9 of Set 2 | belaya gora
# Processing Record 10 of Set 2 | havre-saint-pierre
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | falmouth
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | hays
# Processing Record 17 of Set 2 | kahului
# Processing Record 18 of Set 2 | guicheng
# City not found. Skipping...
# Processing Record 19 of Set 2 | kijang
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | matveyevka
# Processing Record 22 of Set 2 | ancud
# Processing Record 23 of Set 2 | geraldton
# Processing Record 24 of Set 2 | rio gallegos
# Processing Record 25 of Set 2 | letka
# Processing Record 26 of Set 2 | lorengau
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | santa rosalia
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | kormend
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | richards bay
# Processing Record 33 of Set 2 | alice springs
# Processing Record 34 of Set 2 | xuzhou
# Processing Record 35 of Set 2 | port elizabeth
# Processing Record 36 of Set 2 | guasdualito
# Processing Record 37 of Set 2 | sovetskiy
# Processing Record 38 of Set 2 | alofi
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | hofu
# Processing Record 41 of Set 2 | saint-georges
# Processing Record 42 of Set 2 | sitka
# Processing Record 43 of Set 2 | kununurra
# Processing Record 44 of Set 2 | torre del campo
# Processing Record 45 of Set 2 | narrabri
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | kidal
# Processing Record 48 of Set 2 | ozernovskiy
# Processing Record 49 of Set 2 | bereda
# Processing Record 50 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 3 | namatanai
# Processing Record 2 of Set 3 | lewisporte
# Processing Record 3 of Set 3 | chuy
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | sembakung
# Processing Record 6 of Set 3 | waslala
# Processing Record 7 of Set 3 | gamba
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | pyapon
# Processing Record 10 of Set 3 | booue
# Processing Record 11 of Set 3 | qunduz
# Processing Record 12 of Set 3 | sanary-sur-mer
# Processing Record 13 of Set 3 | likasi
# Processing Record 14 of Set 3 | cozumel
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | namwala
# Processing Record 18 of Set 3 | ferme-neuve
# Processing Record 19 of Set 3 | husavik
# Processing Record 20 of Set 3 | fortuna
# Processing Record 21 of Set 3 | valparaiso
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | sosnovka
# Processing Record 25 of Set 3 | kirensk
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | luwingu
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | obo
# Processing Record 31 of Set 3 | zharkent
# Processing Record 32 of Set 3 | sambava
# Processing Record 33 of Set 3 | bolonchen
# City not found. Skipping...
# Processing Record 34 of Set 3 | vao
# Processing Record 35 of Set 3 | bengkulu
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | tatarsk
# Processing Record 38 of Set 3 | itoman
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | ndele
# Processing Record 42 of Set 3 | severo-kurilsk
# Processing Record 43 of Set 3 | sao filipe
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | khovu-aksy
# Processing Record 46 of Set 3 | grafenau
# Processing Record 47 of Set 3 | puerto escondido
# Processing Record 48 of Set 3 | vannes
# Processing Record 49 of Set 3 | ulladulla
# Processing Record 50 of Set 3 | qaanaaq
# Processing Record 1 of Set 4 | tolaga bay
# Processing Record 2 of Set 4 | valle de allende
# Processing Record 3 of Set 4 | trairi
# Processing Record 4 of Set 4 | tiksi
# Processing Record 5 of Set 4 | hovd
# Processing Record 6 of Set 4 | deputatskiy
# Processing Record 7 of Set 4 | talnakh
# Processing Record 8 of Set 4 | cairns
# Processing Record 9 of Set 4 | doha
# Processing Record 10 of Set 4 | iracoubo
# Processing Record 11 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 4 | praia da vitoria
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | hualmay
# Processing Record 15 of Set 4 | cedar city
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | caravelas
# Processing Record 18 of Set 4 | saldanha
# Processing Record 19 of Set 4 | nelson bay
# Processing Record 20 of Set 4 | krasnoselkup
# Processing Record 21 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 4 | kristiansund
# Processing Record 23 of Set 4 | saint-joseph
# Processing Record 24 of Set 4 | qasigiannguit
# Processing Record 25 of Set 4 | saint anthony
# Processing Record 26 of Set 4 | matagami
# Processing Record 27 of Set 4 | comarapa
# Processing Record 28 of Set 4 | beringovskiy
# Processing Record 29 of Set 4 | miyako
# Processing Record 30 of Set 4 | vanimo
# Processing Record 31 of Set 4 | kysyl-syr
# Processing Record 32 of Set 4 | hambantota
# Processing Record 33 of Set 4 | hof
# Processing Record 34 of Set 4 | grindavik
# Processing Record 35 of Set 4 | karatau
# Processing Record 36 of Set 4 | oeiras do para
# Processing Record 37 of Set 4 | kichera
# Processing Record 38 of Set 4 | tuatapere
# Processing Record 39 of Set 4 | ouadda
# Processing Record 40 of Set 4 | solvychegodsk
# Processing Record 41 of Set 4 | les escoumins
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | giyani
# Processing Record 44 of Set 4 | naziya
# Processing Record 45 of Set 4 | teeli
# Processing Record 46 of Set 4 | shelburne
# Processing Record 47 of Set 4 | anuradhapura
# Processing Record 48 of Set 4 | port lincoln
# Processing Record 49 of Set 4 | haines junction
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | macusani
# Processing Record 2 of Set 5 | newport
# Processing Record 3 of Set 5 | bajo baudo
# City not found. Skipping...
# Processing Record 4 of Set 5 | te anau
# Processing Record 5 of Set 5 | krasnogorodsk
# Processing Record 6 of Set 5 | siderno
# Processing Record 7 of Set 5 | vryheid
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | iqaluit
# Processing Record 10 of Set 5 | parkes
# Processing Record 11 of Set 5 | hay river
# Processing Record 12 of Set 5 | cesena
# Processing Record 13 of Set 5 | sarh
# Processing Record 14 of Set 5 | plyussa
# Processing Record 15 of Set 5 | conde
# Processing Record 16 of Set 5 | curup
# Processing Record 17 of Set 5 | santa maria
# Processing Record 18 of Set 5 | cravo norte
# Processing Record 19 of Set 5 | ouro preto do oeste
# Processing Record 20 of Set 5 | princeton
# Processing Record 21 of Set 5 | angra
# City not found. Skipping...
# Processing Record 22 of Set 5 | portland
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | sisophon
# Processing Record 25 of Set 5 | malpe
# Processing Record 26 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 5 | nome
# Processing Record 28 of Set 5 | sept-iles
# Processing Record 29 of Set 5 | lebu
# Processing Record 30 of Set 5 | nanchang
# Processing Record 31 of Set 5 | buenos aires
# Processing Record 32 of Set 5 | chabahar
# Processing Record 33 of Set 5 | port hardy
# Processing Record 34 of Set 5 | kiruna
# Processing Record 35 of Set 5 | beyneu
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 38 of Set 5 | dikson
# Processing Record 39 of Set 5 | yerbogachen
# Processing Record 40 of Set 5 | australind
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | svatove
# Processing Record 43 of Set 5 | abu samrah
# Processing Record 44 of Set 5 | roald
# Processing Record 45 of Set 5 | yazd
# Processing Record 46 of Set 5 | flinders
# Processing Record 47 of Set 5 | narsaq
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | azov
# Processing Record 50 of Set 5 | esperance
# Processing Record 1 of Set 6 | mosquera
# Processing Record 2 of Set 6 | la plata
# Processing Record 3 of Set 6 | kloulklubed
# Processing Record 4 of Set 6 | chokurdakh
# Processing Record 5 of Set 6 | eureka
# Processing Record 6 of Set 6 | masaurhi
# Processing Record 7 of Set 6 | cerna
# Processing Record 8 of Set 6 | warri
# Processing Record 9 of Set 6 | eyl
# Processing Record 10 of Set 6 | alta floresta
# Processing Record 11 of Set 6 | beloha
# Processing Record 12 of Set 6 | dunedin
# Processing Record 13 of Set 6 | whitehorse
# Processing Record 14 of Set 6 | yambio
# Processing Record 15 of Set 6 | adre
# Processing Record 16 of Set 6 | murray bridge
# Processing Record 17 of Set 6 | kaitangata
# Processing Record 18 of Set 6 | spirit river
# Processing Record 19 of Set 6 | killarney
# Processing Record 20 of Set 6 | clyde river
# Processing Record 21 of Set 6 | poum
# Processing Record 22 of Set 6 | solola
# Processing Record 23 of Set 6 | faya
# Processing Record 24 of Set 6 | sierpc
# Processing Record 25 of Set 6 | kruisfontein
# Processing Record 26 of Set 6 | chemal
# Processing Record 27 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 6 | capitao poco
# Processing Record 29 of Set 6 | tucurui
# Processing Record 30 of Set 6 | amga
# Processing Record 31 of Set 6 | cururupu
# Processing Record 32 of Set 6 | maniwaki
# Processing Record 33 of Set 6 | jieshi
# Processing Record 34 of Set 6 | muzquiz
# City not found. Skipping...
# Processing Record 35 of Set 6 | nemuro
# Processing Record 36 of Set 6 | arraial do cabo
# Processing Record 37 of Set 6 | vardo
# Processing Record 38 of Set 6 | spas-klepiki
# Processing Record 39 of Set 6 | barra do bugres
# Processing Record 40 of Set 6 | gasa
# Processing Record 41 of Set 6 | pangnirtung
# Processing Record 42 of Set 6 | balabac
# Processing Record 43 of Set 6 | luanda
# Processing Record 44 of Set 6 | anaconda
# Processing Record 45 of Set 6 | cheney
# Processing Record 46 of Set 6 | russell
# Processing Record 47 of Set 6 | altay
# Processing Record 48 of Set 6 | soe
# Processing Record 49 of Set 6 | canmore
# Processing Record 50 of Set 6 | mendi
# Processing Record 1 of Set 7 | palmer
# Processing Record 2 of Set 7 | dingle
# Processing Record 3 of Set 7 | gilgit
# Processing Record 4 of Set 7 | chumikan
# Processing Record 5 of Set 7 | yulara
# Processing Record 6 of Set 7 | pontypool
# Processing Record 7 of Set 7 | saint-philippe
# Processing Record 8 of Set 7 | luderitz
# Processing Record 9 of Set 7 | okmulgee
# Processing Record 10 of Set 7 | bathsheba
# Processing Record 11 of Set 7 | issoudun
# Processing Record 12 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 7 | vostok
# Processing Record 14 of Set 7 | huambo
# Processing Record 15 of Set 7 | saint-augustin
# Processing Record 16 of Set 7 | miranda
# Processing Record 17 of Set 7 | saskylakh
# Processing Record 18 of Set 7 | romanovka
# Processing Record 19 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 7 | rockland
# Processing Record 21 of Set 7 | lavrentiya
# Processing Record 22 of Set 7 | mansehra
# Processing Record 23 of Set 7 | porbandar
# Processing Record 24 of Set 7 | ladario
# Processing Record 25 of Set 7 | hami
# Processing Record 26 of Set 7 | reguengos de monsaraz
# Processing Record 27 of Set 7 | ojinaga
# Processing Record 28 of Set 7 | dalby
# Processing Record 29 of Set 7 | kavieng
# Processing Record 30 of Set 7 | taoudenni
# Processing Record 31 of Set 7 | macesu de sus
# Processing Record 32 of Set 7 | mishkino
# Processing Record 33 of Set 7 | cidreira
# Processing Record 34 of Set 7 | mukhen
# Processing Record 35 of Set 7 | itaituba
# Processing Record 36 of Set 7 | san cristobal
# Processing Record 37 of Set 7 | tabou
# Processing Record 38 of Set 7 | batemans bay
# Processing Record 39 of Set 7 | kongolo
# Processing Record 40 of Set 7 | tecoanapa
# Processing Record 41 of Set 7 | sobradinho
# Processing Record 42 of Set 7 | solnechnyy
# Processing Record 43 of Set 7 | slantsy
# Processing Record 44 of Set 7 | lompoc
# Processing Record 45 of Set 7 | eirunepe
# Processing Record 46 of Set 7 | santos dumont
# Processing Record 47 of Set 7 | kalakamati
# Processing Record 48 of Set 7 | lufilufi
# Processing Record 49 of Set 7 | mount isa
# Processing Record 50 of Set 7 | mpanda
# Processing Record 1 of Set 8 | nanortalik
# Processing Record 2 of Set 8 | avdon
# Processing Record 3 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 8 | kuryk
# Processing Record 5 of Set 8 | sao jose da tapera
# Processing Record 6 of Set 8 | payo
# Processing Record 7 of Set 8 | coxim
# Processing Record 8 of Set 8 | tual
# Processing Record 9 of Set 8 | black river
# Processing Record 10 of Set 8 | muborak
# Processing Record 11 of Set 8 | ilulissat
# Processing Record 12 of Set 8 | nabire
# Processing Record 13 of Set 8 | san policarpo
# Processing Record 14 of Set 8 | goderich
# Processing Record 15 of Set 8 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 16 of Set 8 | piet retief
# Processing Record 17 of Set 8 | sobolevo
# Processing Record 18 of Set 8 | roma
# Processing Record 19 of Set 8 | fuerte olimpo
# Processing Record 20 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 8 | ballina
# Processing Record 22 of Set 8 | te karaka
# Processing Record 23 of Set 8 | belen
# Processing Record 24 of Set 8 | minsk
# Processing Record 25 of Set 8 | oksfjord
# Processing Record 26 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 8 | alihe
# Processing Record 28 of Set 8 | neopolis
# Processing Record 29 of Set 8 | pandan
# Processing Record 30 of Set 8 | egvekinot
# Processing Record 31 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 8 | jijiga
# Processing Record 33 of Set 8 | castro
# Processing Record 34 of Set 8 | bayir
# Processing Record 35 of Set 8 | mahebourg
# Processing Record 36 of Set 8 | waipawa
# Processing Record 37 of Set 8 | upanema
# Processing Record 38 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 8 | kurilsk
# Processing Record 41 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 8 | lodwar
# Processing Record 43 of Set 8 | lata
# Processing Record 44 of Set 8 | killam
# Processing Record 45 of Set 8 | waingapu
# Processing Record 46 of Set 8 | isangel
# Processing Record 47 of Set 8 | shalinskoye
# Processing Record 48 of Set 8 | port moresby
# Processing Record 49 of Set 8 | poronaysk
# Processing Record 50 of Set 8 | skagen
# Processing Record 1 of Set 9 | grand gaube
# Processing Record 2 of Set 9 | virginia beach
# Processing Record 3 of Set 9 | leningradskiy
# Processing Record 4 of Set 9 | harboore
# Processing Record 5 of Set 9 | padang
# Processing Record 6 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 9 | klaksvik
# Processing Record 8 of Set 9 | fengkou
# Processing Record 9 of Set 9 | lazaro cardenas
# Processing Record 10 of Set 9 | ontario
# Processing Record 11 of Set 9 | blagoveshchensk
# Processing Record 12 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 9 | jamalpur
# Processing Record 14 of Set 9 | yuncheng
# Processing Record 15 of Set 9 | san rafael
# Processing Record 16 of Set 9 | chinsali
# Processing Record 17 of Set 9 | coquimbo
# Processing Record 18 of Set 9 | wendo
# Processing Record 19 of Set 9 | kieta
# Processing Record 20 of Set 9 | muravlenko
# Processing Record 21 of Set 9 | asau
# Processing Record 22 of Set 9 | hofn
# Processing Record 23 of Set 9 | cherskiy
# Processing Record 24 of Set 9 | sal rei
# Processing Record 25 of Set 9 | half moon bay
# Processing Record 26 of Set 9 | victor harbor
# Processing Record 27 of Set 9 | jacqueville
# Processing Record 28 of Set 9 | sabang
# Processing Record 29 of Set 9 | ouahigouya
# Processing Record 30 of Set 9 | okha
# Processing Record 31 of Set 9 | vila velha
# Processing Record 32 of Set 9 | san patricio
# Processing Record 33 of Set 9 | bambous virieux
# Processing Record 34 of Set 9 | abu dhabi
# Processing Record 35 of Set 9 | trebinje
# Processing Record 36 of Set 9 | lewistown
# Processing Record 37 of Set 9 | batagay
# Processing Record 38 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 9 | varfurile
# Processing Record 40 of Set 9 | nautla
# Processing Record 41 of Set 9 | homer
# Processing Record 42 of Set 9 | saint-pierre
# Processing Record 43 of Set 9 | maralal
# Processing Record 44 of Set 9 | labuan
# Processing Record 45 of Set 9 | qinzhou
# Processing Record 46 of Set 9 | houma
# Processing Record 47 of Set 9 | kupang
# Processing Record 48 of Set 9 | bilasipara
# Processing Record 49 of Set 9 | komsomolskiy
# Processing Record 50 of Set 9 | ajdabiya
# Processing Record 1 of Set 10 | baglan
# Processing Record 2 of Set 10 | wagar
# Processing Record 3 of Set 10 | amahai
# Processing Record 4 of Set 10 | kalia
# Processing Record 5 of Set 10 | quang ngai
# Processing Record 6 of Set 10 | puerto baquerizo moreno
# Processing Record 7 of Set 10 | thurso
# Processing Record 8 of Set 10 | celestun
# Processing Record 9 of Set 10 | kerema
# Processing Record 10 of Set 10 | jorochito
# Processing Record 11 of Set 10 | clinton
# Processing Record 12 of Set 10 | santa cruz
# Processing Record 13 of Set 10 | anqing
# Processing Record 14 of Set 10 | marawi
# Processing Record 15 of Set 10 | bermejillo
# Processing Record 16 of Set 10 | leshukonskoye
# Processing Record 17 of Set 10 | ambilobe
# Processing Record 18 of Set 10 | savonlinna
# Processing Record 19 of Set 10 | kulhudhuffushi
# Processing Record 20 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 10 | trelew
# Processing Record 22 of Set 10 | college
# Processing Record 23 of Set 10 | kastrakion
# Processing Record 24 of Set 10 | nioro
# Processing Record 25 of Set 10 | namie
# Processing Record 26 of Set 10 | gravdal
# Processing Record 27 of Set 10 | maloy
# Processing Record 28 of Set 10 | port-gentil
# Processing Record 29 of Set 10 | andenes
# Processing Record 30 of Set 10 | vilyuysk
# Processing Record 31 of Set 10 | hokitika
# Processing Record 32 of Set 10 | qaqortoq
# Processing Record 33 of Set 10 | polunochnoye
# Processing Record 34 of Set 10 | lensk
# Processing Record 35 of Set 10 | teruel
# Processing Record 36 of Set 10 | port blair
# Processing Record 37 of Set 10 | zakamensk
# Processing Record 38 of Set 10 | maracacume
# Processing Record 39 of Set 10 | fernley
# Processing Record 40 of Set 10 | ketchikan
# Processing Record 41 of Set 10 | zhigansk
# Processing Record 42 of Set 10 | puerto del rosario
# Processing Record 43 of Set 10 | hobyo
# Processing Record 44 of Set 10 | emba
# Processing Record 45 of Set 10 | honiara
# Processing Record 46 of Set 10 | san jose
# Processing Record 47 of Set 10 | yaypan
# Processing Record 48 of Set 10 | norman wells
# Processing Record 49 of Set 10 | puerto madryn
# Processing Record 50 of Set 10 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 1 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 2 of Set 11 | helong
# Processing Record 3 of Set 11 | lekhovon
# City not found. Skipping...
# Processing Record 4 of Set 11 | karratha
# Processing Record 5 of Set 11 | srivardhan
# Processing Record 6 of Set 11 | rocha
# Processing Record 7 of Set 11 | chapais
# Processing Record 8 of Set 11 | arlit
# Processing Record 9 of Set 11 | griffith
# Processing Record 10 of Set 11 | atar
# Processing Record 11 of Set 11 | revda
# Processing Record 12 of Set 11 | santa isabel do rio negro
# Processing Record 13 of Set 11 | la ronge
# Processing Record 14 of Set 11 | nhulunbuy
# Processing Record 15 of Set 11 | leh
# Processing Record 16 of Set 11 | majayjay
# Processing Record 17 of Set 11 | margate
# Processing Record 18 of Set 11 | wajima
# Processing Record 19 of Set 11 | strezhevoy
# Processing Record 20 of Set 11 | mogadishu
# Processing Record 21 of Set 11 | watsa
# Processing Record 22 of Set 11 | maturin
# Processing Record 23 of Set 11 | khor
# Processing Record 24 of Set 11 | yar-sale
# Processing Record 25 of Set 11 | loikaw
# Processing Record 26 of Set 11 | biltine
# Processing Record 27 of Set 11 | porto velho
# Processing Record 28 of Set 11 | bassar
# Processing Record 29 of Set 11 | amarante do maranhao
# Processing Record 30 of Set 11 | bangar
# Processing Record 31 of Set 11 | meulaboh
# Processing Record 32 of Set 11 | zabaykalsk
# Processing Record 33 of Set 11 | uttiramerur
# Processing Record 34 of Set 11 | boueni
# Processing Record 35 of Set 11 | sao joao da barra
# Processing Record 36 of Set 11 | kangaatsiaq
# Processing Record 37 of Set 11 | cooma
# Processing Record 38 of Set 11 | vestmannaeyjar
# Processing Record 39 of Set 11 | rawson
# Processing Record 40 of Set 11 | tignere
# Processing Record 41 of Set 11 | pangai
# Processing Record 42 of Set 11 | amnat charoen
# Processing Record 43 of Set 11 | tautira
# Processing Record 44 of Set 11 | road town
# Processing Record 45 of Set 11 | buala
# Processing Record 46 of Set 11 | kamina
# Processing Record 47 of Set 11 | khani
# Processing Record 48 of Set 11 | peniche
# Processing Record 49 of Set 11 | ixtapa
# Processing Record 50 of Set 11 | boffa
# Processing Record 1 of Set 12 | tazovskiy
# Processing Record 2 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 12 | kodinsk
# Processing Record 4 of Set 12 | miri
# Processing Record 5 of Set 12 | mangaratiba
# Processing Record 6 of Set 12 | adwa
# Processing Record 7 of Set 12 | laguna
# Processing Record 8 of Set 12 | northam
# Processing Record 9 of Set 12 | antofagasta
# Processing Record 10 of Set 12 | manzanillo
# Processing Record 11 of Set 12 | bardiyah
# Processing Record 12 of Set 12 | wanxian
# Processing Record 13 of Set 12 | aklavik
# Processing Record 14 of Set 12 | okhotsk
# Processing Record 15 of Set 12 | ginda
# Processing Record 16 of Set 12 | nishihara
# Processing Record 17 of Set 12 | wentzville
# Processing Record 18 of Set 12 | kudahuvadhoo
# Processing Record 19 of Set 12 | debre zeyit
# Processing Record 20 of Set 12 | tura
# Processing Record 21 of Set 12 | port shepstone
# Processing Record 22 of Set 12 | bougouni
# Processing Record 23 of Set 12 | pangkalanbuun
# Processing Record 24 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 12 | linxia
# Processing Record 26 of Set 12 | catumbela
# Processing Record 27 of Set 12 | elko
# Processing Record 28 of Set 12 | sao jose da coroa grande
# Processing Record 29 of Set 12 | bestobe
# Processing Record 30 of Set 12 | hoquiam
# Processing Record 31 of Set 12 | chenzhou
# Processing Record 32 of Set 12 | yinchuan
# Processing Record 33 of Set 12 | bajil
# Processing Record 34 of Set 12 | sola
# Processing Record 35 of Set 12 | hammerfest
# Processing Record 36 of Set 12 | healdsburg
# Processing Record 37 of Set 12 | mari-turek
# Processing Record 38 of Set 12 | severo-yeniseyskiy
# Processing Record 39 of Set 12 | beipiao
# Processing Record 40 of Set 12 | vernon
# Processing Record 41 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 12 | marsaxlokk
# Processing Record 43 of Set 12 | odienne
# Processing Record 44 of Set 12 | gubkinskiy
# Processing Record 45 of Set 12 | bolgatanga
# Processing Record 46 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 12 | rio grande
# Processing Record 48 of Set 12 | tessalit
# Processing Record 49 of Set 12 | bilibino
# Processing Record 50 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 13 | churapcha
# Processing Record 2 of Set 13 | erzin
# Processing Record 3 of Set 13 | plettenberg bay
# Processing Record 4 of Set 13 | ternate
# Processing Record 5 of Set 13 | salto
# Processing Record 6 of Set 13 | tromso
# Processing Record 7 of Set 13 | fairbanks
# Processing Record 8 of Set 13 | belawan
# Processing Record 9 of Set 13 | nanakuli
# Processing Record 10 of Set 13 | barranca
# Processing Record 11 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 13 | zachagansk
# City not found. Skipping...
# Processing Record 13 of Set 13 | brae
# Processing Record 14 of Set 13 | mahibadhoo
# Processing Record 15 of Set 13 | motihari
# Processing Record 16 of Set 13 | namibe
# Processing Record 17 of Set 13 | colonia
# Processing Record 18 of Set 13 | bull savanna
# Processing Record 19 of Set 13 | nikolayevsk-na-amure
# Processing Record 20 of Set 13 | jobner
# Processing Record 21 of Set 13 | bearsden
# Processing Record 22 of Set 13 | meybod
# Processing Record 23 of Set 13 | oyon
# Processing Record 24 of Set 13 | vila franca do campo
# Processing Record 25 of Set 13 | miles city
# Processing Record 26 of Set 13 | kokopo
# Processing Record 27 of Set 13 | mabaruma
# Processing Record 28 of Set 13 | marzuq
# Processing Record 29 of Set 13 | orbetello
# Processing Record 30 of Set 13 | druzhba
# Processing Record 31 of Set 13 | sosnovo-ozerskoye
# Processing Record 32 of Set 13 | sao raimundo nonato
# Processing Record 33 of Set 13 | mirnyy
# Processing Record 34 of Set 13 | gagra
# Processing Record 35 of Set 13 | samarinda
# Processing Record 36 of Set 13 | ko samui
# Processing Record 37 of Set 13 | gao
# Processing Record 38 of Set 13 | porto franco
# Processing Record 39 of Set 13 | kilingi-nomme
# Processing Record 40 of Set 13 | bykivka
# Processing Record 41 of Set 13 | champerico
# Processing Record 42 of Set 13 | siocon
# Processing Record 43 of Set 13 | shimoda
# Processing Record 44 of Set 13 | atikokan
# Processing Record 45 of Set 13 | otradnoye
# Processing Record 46 of Set 13 | chumphon
# Processing Record 47 of Set 13 | bridlington
# Processing Record 48 of Set 13 | bani walid
# Processing Record 49 of Set 13 | bolkhov
# Processing Record 50 of Set 13 | karachi
# Processing Record 1 of Set 14 | luau
# Processing Record 2 of Set 14 | samarai
# Processing Record 3 of Set 14 | conakry
# Processing Record 4 of Set 14 | ratne
# Processing Record 5 of Set 14 | las cruces
# Processing Record 6 of Set 14 | bahia blanca
# Processing Record 7 of Set 14 | salisbury
# Processing Record 8 of Set 14 | two rivers
# Processing Record 9 of Set 14 | nador
# Processing Record 10 of Set 14 | labuhan
# Processing Record 11 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 14 | beian
# Processing Record 13 of Set 14 | mutoko
# Processing Record 14 of Set 14 | samarkand
# Processing Record 15 of Set 14 | iralaya
# Processing Record 16 of Set 14 | prachuap khiri khan
# Processing Record 17 of Set 14 | acapulco
# Processing Record 18 of Set 14 | general roca
# Processing Record 19 of Set 14 | porto novo
# Processing Record 20 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 21 of Set 14 | salinas
# Processing Record 22 of Set 14 | pingyin
# Processing Record 23 of Set 14 | benghazi
# Processing Record 24 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 14 | omsukchan
# Processing Record 26 of Set 14 | san andres
# Processing Record 27 of Set 14 | mana
# Processing Record 28 of Set 14 | avera
# Processing Record 29 of Set 14 | tanout
# Processing Record 30 of Set 14 | placido de castro
# Processing Record 31 of Set 14 | bedele
# Processing Record 32 of Set 14 | antalaha
# Processing Record 33 of Set 14 | begunitsy
# Processing Record 34 of Set 14 | manicore
# Processing Record 35 of Set 14 | ubinskoye
# Processing Record 36 of Set 14 | meiganga
# Processing Record 37 of Set 14 | bykovo
# Processing Record 38 of Set 14 | goteborg
# City not found. Skipping...
# Processing Record 39 of Set 14 | touba
# Processing Record 40 of Set 14 | tomatlan
# Processing Record 41 of Set 14 | padilla
# Processing Record 42 of Set 14 | fort nelson
# Processing Record 43 of Set 14 | marsa matruh
# Processing Record 44 of Set 14 | akdepe
# Processing Record 45 of Set 14 | berikulskiy
# City not found. Skipping...
# Processing Record 46 of Set 14 | adrar
# Processing Record 47 of Set 14 | owando
# Processing Record 48 of Set 14 | airai
# Processing Record 49 of Set 14 | arzgir
# Processing Record 50 of Set 14 | ahipara
# Processing Record 1 of Set 15 | orebro
# Processing Record 2 of Set 15 | milkovo
# Processing Record 3 of Set 15 | coihaique
# Processing Record 4 of Set 15 | xinzhi
# Processing Record 5 of Set 15 | chala
# Processing Record 6 of Set 15 | iskateley
# Processing Record 7 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 15 | ust-tsilma
# Processing Record 9 of Set 15 | sao felix do xingu
# Processing Record 10 of Set 15 | shubarshi
# Processing Record 11 of Set 15 | shache
# Processing Record 12 of Set 15 | udachnyy
# Processing Record 13 of Set 15 | porciuncula
# Processing Record 14 of Set 15 | aykhal
# Processing Record 15 of Set 15 | tambopata
# Processing Record 16 of Set 15 | kailua
# Processing Record 17 of Set 15 | luis correia
# Processing Record 18 of Set 15 | bubaque
# Processing Record 19 of Set 15 | brawley
# Processing Record 20 of Set 15 | katete
# Processing Record 21 of Set 15 | istisu
# Processing Record 22 of Set 15 | callaway
# Processing Record 23 of Set 15 | rylsk
# Processing Record 24 of Set 15 | diffa
# Processing Record 25 of Set 15 | silopi
# Processing Record 26 of Set 15 | shieli
# Processing Record 27 of Set 15 | maumere
# Processing Record 28 of Set 15 | frei paulo
# Processing Record 29 of Set 15 | kostomuksha
# Processing Record 30 of Set 15 | marathon
# Processing Record 31 of Set 15 | fukue
# Processing Record 32 of Set 15 | zhangye
# Processing Record 33 of Set 15 | orotukan
# Processing Record 34 of Set 15 | aitape
# Processing Record 35 of Set 15 | kleck
# City not found. Skipping...
# Processing Record 36 of Set 15 | huarmey
# Processing Record 37 of Set 15 | vega de alatorre
# Processing Record 38 of Set 15 | kamaris
# Processing Record 39 of Set 15 | viedma
# Processing Record 40 of Set 15 | cap malheureux
# Processing Record 41 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 42 of Set 15 | santa vitoria do palmar
# Processing Record 43 of Set 15 | luang prabang
# Processing Record 44 of Set 15 | talaya
# Processing Record 45 of Set 15 | quatre cocos
# Processing Record 46 of Set 15 | kargasok
# Processing Record 47 of Set 15 | urumqi
# Processing Record 48 of Set 15 | rundu
# Processing Record 49 of Set 15 | acajutla
# Processing Record 50 of Set 15 | sungaipenuh
# Processing Record 1 of Set 16 | uglovskoye
# Processing Record 2 of Set 16 | quelimane
# Processing Record 3 of Set 16 | tigre
# Processing Record 4 of Set 16 | naze
# Processing Record 5 of Set 16 | delta
# Processing Record 6 of Set 16 | okahandja
# Processing Record 7 of Set 16 | krasnyy profintern
# Processing Record 8 of Set 16 | khash
# Processing Record 9 of Set 16 | inhambane
# Processing Record 10 of Set 16 | majene
# Processing Record 11 of Set 16 | punta cardon
# Processing Record 12 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 16 | kungalv
# Processing Record 14 of Set 16 | kisaran
# Processing Record 15 of Set 16 | sechura
# Processing Record 16 of Set 16 | los llanos de aridane
# Processing Record 17 of Set 16 | silale
# Processing Record 18 of Set 16 | pauini
# Processing Record 19 of Set 16 | fare
# Processing Record 20 of Set 16 | maniitsoq
# Processing Record 21 of Set 16 | maragogi
# Processing Record 22 of Set 16 | aksu
# Processing Record 23 of Set 16 | tarata
# Processing Record 24 of Set 16 | inuvik
# Processing Record 25 of Set 16 | aasiaat
# Processing Record 26 of Set 16 | zhaoyuan
# Processing Record 27 of Set 16 | ostrovnoy
# Processing Record 28 of Set 16 | bystryy istok
# Processing Record 29 of Set 16 | reconquista
# Processing Record 30 of Set 16 | zeya
# Processing Record 31 of Set 16 | stornoway
# Processing Record 32 of Set 16 | posse
# Processing Record 33 of Set 16 | aubenas
# Processing Record 34 of Set 16 | matara
# Processing Record 35 of Set 16 | gornyy
# Processing Record 36 of Set 16 | asyut
# Processing Record 37 of Set 16 | concepcion del uruguay
# Processing Record 38 of Set 16 | tubruq
# City not found. Skipping...
# Processing Record 39 of Set 16 | san miguel
# Processing Record 40 of Set 16 | necochea
# Processing Record 41 of Set 16 | nagua
# Processing Record 42 of Set 16 | albion
# Processing Record 43 of Set 16 | katsuura
# Processing Record 44 of Set 16 | manado
# Processing Record 45 of Set 16 | tefe
# Processing Record 46 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 16 | ambon
# Processing Record 48 of Set 16 | jian
# Processing Record 49 of Set 16 | magaria
# Processing Record 50 of Set 16 | pa sang
# Processing Record 1 of Set 17 | killybegs
# Processing Record 2 of Set 17 | oxford
# Processing Record 3 of Set 17 | abnub
# Processing Record 4 of Set 17 | odweyne
# Processing Record 5 of Set 17 | barabai
# Processing Record 6 of Set 17 | jambi
# Processing Record 7 of Set 17 | poretskoye
# Processing Record 8 of Set 17 | mount gambier
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 755

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Khatanga  71.9667  102.5000    -28.48        97         100
# 1     Punta Arenas -53.1500  -70.9167     53.71        35          20
# 2          Mataura -46.1927  168.8643     58.48        69          89
# 3      Henties Bay -22.1160   14.2845     62.87        75         100
# 4           Torbay  47.6666  -52.7314     36.27        92          40
# ..             ...      ...       ...       ...       ...         ...
# 750        Odweyne   9.4092   45.0640     70.59        55          54
# 751        Barabai  -2.5833  115.3833     73.98        99         100
# 752          Jambi  -1.6000  103.6167     74.03        98          99
# 753     Poretskoye  55.1974   46.3291     17.82        91          37
# 754  Mount Gambier -37.8333  140.7667     51.44        74          12
#
#      Wind Speed Country                 Date Current Description
# 0          1.52      RU  2022-11-19 20:39:41     overcast clouds
# 1         31.07      CL  2022-11-19 20:40:43          few clouds
# 2          4.16      NZ  2022-11-19 20:38:54     overcast clouds
# 3          7.38      NA  2022-11-19 20:44:24     overcast clouds
# 4         10.36      CA  2022-11-19 20:35:38         shower rain
# ..          ...     ...                  ...                 ...
# 750        4.50      SO  2022-11-19 21:09:12       broken clouds
# 751        0.83      ID  2022-11-19 21:09:13     overcast clouds
# 752        2.21      ID  2022-11-19 21:09:13     overcast clouds
# 753       10.00      RU  2022-11-19 21:09:14    scattered clouds
# 754       14.16      AU  2022-11-19 21:09:14          few clouds
#
# [755 rows x 10 columns]

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga  71.9667  102.5000    -28.48        97         100
# 1  Punta Arenas -53.1500  -70.9167     53.71        35          20
# 2       Mataura -46.1927  168.8643     58.48        69          89
# 3   Henties Bay -22.1160   14.2845     62.87        75         100
# 4        Torbay  47.6666  -52.7314     36.27        92          40
# 5    Nikolskoye  59.7035   30.7861     22.91        79          94
# 6      Aripuana  -9.1667  -60.6333     81.66        69          95
# 7        Hobart -42.8794  147.3294     55.26        91         100
# 8       Itarema  -2.9248  -39.9167     79.77        75          74
# 9       Rikitea -23.1203 -134.9692     71.08        67          93
#
#    Wind Speed Country                 Date Current Description
# 0        1.52      RU  2022-11-19 20:39:41     overcast clouds
# 1       31.07      CL  2022-11-19 20:40:43          few clouds
# 2        4.16      NZ  2022-11-19 20:38:54     overcast clouds
# 3        7.38      NA  2022-11-19 20:44:24     overcast clouds
# 4       10.36      CA  2022-11-19 20:35:38         shower rain
# 5        7.61      RU  2022-11-19 20:44:25     overcast clouds
# 6        0.51      BR  2022-11-19 20:44:25          light rain
# 7       10.36      AU  2022-11-19 20:44:26          light rain
# 8       15.68      BR  2022-11-19 20:44:26       broken clouds
# 9        9.28      PF  2022-11-19 20:44:27     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga      RU  71.9667  102.5000    -28.48        97         100
# 1  Punta Arenas      CL -53.1500  -70.9167     53.71        35          20
# 2       Mataura      NZ -46.1927  168.8643     58.48        69          89
# 3   Henties Bay      NA -22.1160   14.2845     62.87        75         100
# 4        Torbay      CA  47.6666  -52.7314     36.27        92          40
#
#    Wind Speed Current Description
# 0        1.52     overcast clouds
# 1       31.07          few clouds
# 2        4.16     overcast clouds
# 3        7.38     overcast clouds
# 4       10.36         shower rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
